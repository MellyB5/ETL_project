# %%
import pandas as pd

# %%
value_ag_df = pd.read_csv("Resources/value_agriculture.csv")
value_ag_df.head()
# Out:
#   Domain Code                            Domain  Area Code    Area  \
# 0          QV  Value of Agricultural Production          7  Angola
# 1          QV  Value of Agricultural Production          7  Angola
# 2          QV  Value of Agricultural Production          7  Angola
# 3          QV  Value of Agricultural Production          7  Angola
# 4          QV  Value of Agricultural Production          7  Angola
#
#    Element Code                                            Element  Item Code  \
# 0           152  Gross Production Value (constant 2014-2016 tho...        661
# 1           152  Gross Production Value (constant 2014-2016 tho...        661
# 2           152  Gross Production Value (constant 2014-2016 tho...        661
# 3           152  Gross Production Value (constant 2014-2016 tho...        661
# 4           152  Gross Production Value (constant 2014-2016 tho...        661
#
#            Item  Year Code  Year         Unit  Value Flag Flag Description
# 0  Cocoa, beans       1961  1961  1000 Int. $    589   Fc  Calculated data
# 1  Cocoa, beans       1962  1962  1000 Int. $    589   Fc  Calculated data
# 2  Cocoa, beans       1963  1963  1000 Int. $    441   Fc  Calculated data
# 3  Cocoa, beans       1964  1964  1000 Int. $    441   Fc  Calculated data
# 4  Cocoa, beans       1965  1965  1000 Int. $    589   Fc  Calculated data

# %%
value_columns = ["Area", "Element", "Year", "Unit", "Value"]
new_value_ag_df = value_ag_df[value_columns].copy()
new_value_ag_df.head()
# Out:
#      Area                                            Element  Year  \
# 0  Angola  Gross Production Value (constant 2014-2016 tho...  1961
# 1  Angola  Gross Production Value (constant 2014-2016 tho...  1962
# 2  Angola  Gross Production Value (constant 2014-2016 tho...  1963
# 3  Angola  Gross Production Value (constant 2014-2016 tho...  1964
# 4  Angola  Gross Production Value (constant 2014-2016 tho...  1965
#
#           Unit  Value
# 0  1000 Int. $    589
# 1  1000 Int. $    589
# 2  1000 Int. $    441
# 3  1000 Int. $    441
# 4  1000 Int. $    589

# %%
new_value_ag_df["Element"] = new_value_ag_df["Element"].str[:22]
new_value_ag_df.head()
# Out:
#      Area                 Element  Year         Unit  Value
# 0  Angola  Gross Production Value  1961  1000 Int. $    589
# 1  Angola  Gross Production Value  1962  1000 Int. $    589
# 2  Angola  Gross Production Value  1963  1000 Int. $    441
# 3  Angola  Gross Production Value  1964  1000 Int. $    441
# 4  Angola  Gross Production Value  1965  1000 Int. $    589

# %%
new_value_ag_df.to_csv("Resources.cleaned_value_ag.csv")
